# %%
from sklearn.datasets import fetch_openml
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier

# %%
# fetch dataset 
statlog_german_credit_data = fetch_openml(data_id=31, as_frame=True)
# data (as pandas dataframes) 

X = statlog_german_credit_data.data
y = statlog_german_credit_data.target
# metadata 
print(X.columns)
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 20)
# (1000,)

# %%
print(X)
y = y.apply(lambda x: 1 if x == 'bad' else 0)
y
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0         6  critical/other existing credit
# 1          0<=X<200        48                   existing paid
# 2       no checking        12  critical/other existing credit
# 3                <0        42                   existing paid
# 4                <0        24              delayed previously
# ..              ...       ...                             ...
# 995     no checking        12                   existing paid
# 996              <0        30                   existing paid
# 997     no checking        12                   existing paid
# 998              <0        45                   existing paid
# 999        0<=X<200        45  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv           1169  no known savings         >=7
# 1               radio/tv           5951              <100      1<=X<4
# 2              education           2096              <100      4<=X<7
# 3    furniture/equipment           7882              <100      4<=X<7
# 4                new car           4870              <100      1<=X<4
# ..                   ...            ...               ...         ...
# 995  furniture/equipment           1736              <100      4<=X<7
# 996             used car           3857              <100      1<=X<4
# 997             radio/tv            804              <100         >=7
# 998             radio/tv           1845              <100      1<=X<4
# 999             used car           4576        100<=X<500  unemployed
#
#      installment_commitment     personal_status other_parties  \
# 0                         4         male single          none
# 1                         2  female div/dep/mar          none
# 2                         2         male single          none
# 3                         2         male single     guarantor
# 4                         3         male single          none
# ..                      ...                 ...           ...
# 995                       3  female div/dep/mar          none
# 996                       4        male div/sep          none
# 997                       4         male single          none
# 998                       4         male single          none
# 999                       3         male single          none
#
#      residence_since property_magnitude  age other_payment_plans   housing  \
# 0                  4        real estate   67                none       own
# 1                  2        real estate   22                none       own
# 2                  3        real estate   49                none       own
# 3                  4     life insurance   45                none  for free
# 4                  4  no known property   53                none  for free
# ..               ...                ...  ...                 ...       ...
# 995                4        real estate   31                none       own
# 996                4     life insurance   40                none       own
# 997                4                car   38                none       own
# 998                4  no known property   23                none  for free
# 999                4                car   27                none       own
#
#      existing_credits                        job  num_dependents  \
# 0                   2                    skilled               1
# 1                   1                    skilled               1
# 2                   1         unskilled resident               2
# 3                   1                    skilled               2
# 4                   2                    skilled               2
# ..                ...                        ...             ...
# 995                 1         unskilled resident               1
# 996                 1  high qualif/self emp/mgmt               1
# 997                 1                    skilled               1
# 998                 1                    skilled               1
# 999                 1                    skilled               1
#
#     own_telephone foreign_worker
# 0             yes            yes
# 1            none            yes
# 2            none            yes
# 3            none            yes
# 4            none            yes
# ..            ...            ...
# 995          none            yes
# 996           yes            yes
# 997          none            yes
# 998           yes            yes
# 999          none            yes
#
# [1000 rows x 20 columns]
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    1
# 999    0
# Name: class, Length: 1000, dtype: category
# Categories (2, int64): [1, 0]

# %%
x_train, x_, y_train, y_ = train_test_split(X, y, test_size=0.30, random_state=1)

# Split the 40% subset above into two: one half for cross validation and the other for the test set
x_cv, x_test, y_cv, y_test = train_test_split(x_, y_, test_size=0.5, random_state=1)

# Delete temporary variables
del x_, y_

print(f"the shape of the training set (input) is: {x_train.shape}")
print(f"the shape of the training set (target) is: {y_train.shape}\n")
print(f"the shape of the cross validation set (input) is: {x_cv.shape}")
print(f"the shape of the cross validation set (target) is: {y_cv.shape}\n")
print(f"the shape of the test set (input) is: {x_test.shape}")
print(f"the shape of the test set (target) is: {y_test.shape}")
# Out:
# the shape of the training set (input) is: (700, 20)
# the shape of the training set (target) is: (700,)
#
# the shape of the cross validation set (input) is: (150, 20)
# the shape of the cross validation set (target) is: (150,)
#
# the shape of the test set (input) is: (150, 20)
# the shape of the test set (target) is: (150,)

# %%
x_train
# Out:
#     checking_status  duration                  credit_history    purpose  \
# 731              <0        24                   existing paid   radio/tv
# 716     no checking        30  critical/other existing credit   radio/tv
# 640              <0        18                   existing paid  education
# 804        0<=X<200        12                   existing paid    new car
# 737              <0        18                   existing paid    new car
# ..              ...       ...                             ...        ...
# 767     no checking        10                   existing paid   used car
# 72               <0         8  critical/other existing credit      other
# 908     no checking        15              delayed previously   used car
# 235              <0        24                   existing paid   radio/tv
# 37            >=200        18                   existing paid   radio/tv
#
#      credit_amount    savings_status  employment  installment_commitment  \
# 731           1987              <100      1<=X<4                       2
# 716           3077  no known savings         >=7                       3
# 640            750              <100  unemployed                       4
# 804           7472  no known savings  unemployed                       1
# 737           4380        100<=X<500      1<=X<4                       3
# ..             ...               ...         ...                     ...
# 767           2901  no known savings          <1                       1
# 72            1164              <100         >=7                       3
# 908           3594              <100          <1                       1
# 235           1823              <100  unemployed                       4
# 37            2100              <100      1<=X<4                       4
#
#         personal_status other_parties  residence_since property_magnitude  \
# 731         male single          none                4        real estate
# 716         male single          none                2                car
# 640  female div/dep/mar          none                1        real estate
# 804  female div/dep/mar          none                2        real estate
# 737         male single          none                4                car
# ..                  ...           ...              ...                ...
# 767  female div/dep/mar          none                4        real estate
# 72          male single          none                4  no known property
# 908  female div/dep/mar          none                2     life insurance
# 235         male single          none                2                car
# 37          male single  co applicant                2        real estate
#
#      age other_payment_plans   housing  existing_credits  \
# 731   21                none      rent                 1
# 716   40                none       own                 2
# 640   27                none       own                 1
# 804   24                none      rent                 1
# 737   35                none       own                 1
# ..   ...                 ...       ...               ...
# 767   31                none      rent                 1
# 72    51                bank  for free                 2
# 908   46                none       own                 2
# 235   30              stores       own                 1
# 37    37              stores       own                 1
#
#                            job  num_dependents own_telephone foreign_worker
# 731         unskilled resident               2          none            yes
# 716                    skilled               2           yes            yes
# 640    unemp/unskilled non res               1          none            yes
# 804    unemp/unskilled non res               1          none            yes
# 737         unskilled resident               2           yes            yes
# ..                         ...             ...           ...            ...
# 767                    skilled               1          none            yes
# 72   high qualif/self emp/mgmt               2           yes            yes
# 908         unskilled resident               1          none            yes
# 235  high qualif/self emp/mgmt               2          none            yes
# 37                     skilled               1          none            yes
#
# [700 rows x 20 columns]

# %%
numerical_features = ['duration', 'credit_amount', 'installment_commitment', 'residence_since', 'age', 'existing_credits', 'num_dependents']
categorical_features = list(set(X.columns) - set(numerical_features))

# %%
# Preprocessing for numerical data: StandardScaler
numerical_transformer = Pipeline(steps=[
    ('poly', PolynomialFeatures(degree=2, include_bias=False)),
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data: OneHotEncoder
categorical_transformer = OneHotEncoder(drop='first')  # drop='first' to avoid the dummy variable trap

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])
preprocessor.fit(x_train)
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('poly',
#                                                   PolynomialFeatures(include_bias=False)),
#                                                  ('scaler', StandardScaler())]),
#                                  ['duration', 'credit_amount',
#                                   'installment_commitment', 'residence_since',
#                                   'age', 'existing_credits',
#                                   'num_dependents']),
#                                 ('cat', OneHotEncoder(drop='first'),
#                                  ['other_parties', 'other_payment_plans', 'job',
#                                   'housing', 'checking_status',
#                                   'foreign_worker', 'credit_history',
#                                   'property_magnitude', 'employment', 'purpose',
#                                   'savings_status', 'personal_status',
#                                   'own_telephone'])])

# %%
X_train_transformed = preprocessor.transform(x_train)

# %%
X_train_transformed.shape
# Out:
# (700, 76)

# %%
# def createModel(optimizer='adam', init='glorot_uniform'):
#     model = Sequential([
#         Dense(256, input_shape=(X_train_transformed.shape[1],), activation='relu', kernel_initializer=init),
#         Dense(128, activation='relu', kernel_initializer=init),
#         Dense(64, activation='relu', kernel_initializer=init),
#         Dense(32, activation='relu', kernel_initializer=init),
#         Dense(16, activation='relu', kernel_initializer=init),
#         Dense(1, activation='sigmoid', kernel_initializer=init)
#     ])
#     model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
#     return model

# %%
keras_model = KerasClassifier(build_fn=createModel,  epochs=100, batch_size=10, verbose=0)
# Create and fit the pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor), ('model', LogisticRegression(max_iter=1000))])

# %%
pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('poly',
#                                                                    PolynomialFeatures(include_bias=False)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'credit_amount',
#                                                    'installment_commitment',
#                                                    'residence_since', 'age',
#                                                    'existing_credits',
#                                                    'num_dependents']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['other_parties',
#                                                    'other_payment_plans', 'job',
#                                                    'housing', 'checking_status',
#                                                    'foreign_worker',
#                                                    'credit_history',
#                                                    'property_magnitude',
#                                                    'employment', 'purpose',
#                                                    'savings_status',
#                                                    'personal_status',
#                                                    'own_telephone'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
# keras_model_ = pipeline.named_steps['model'].model_
# keras_model_.summary()

# %%
# Predict and calculate training error
yhat_train = pipeline.predict(x_train)
train_error = np.mean(yhat_train != y_train)
print(f"Fraction of misclassified training data: {train_error}")

# Predict and calculate cross-validation error
yhat_cv = pipeline.predict(x_cv)
cv_error = np.mean(yhat_cv != y_cv)
print(f"Fraction of misclassified cross-validation data: {cv_error}")
# Out:
# Fraction of misclassified training data: 0.18571428571428572
# Fraction of misclassified cross-validation data: 0.22

# %%
yhat_test = pipeline.predict(x_test)
test_error = np.mean(yhat_test != y_test)
print(f"Fraction of misclassified test data: {test_error}")
df_new = pd.DataFrame({
    'Prediction': yhat_test,
    'Actual Result': y_test
})
finalDataFrame = pd.concat([x_test, df_new], axis=1)
# Out:
# Fraction of misclassified test data: 0.26666666666666666

# %%
finalDataFrame[:50]
# Out:
#     checking_status  duration                  credit_history  \
# 486     no checking        12                   existing paid
# 872              <0        24  critical/other existing credit
# 404        0<=X<200        18              delayed previously
# 911        0<=X<200        24  critical/other existing credit
# 531        0<=X<200        15                   existing paid
# 608     no checking        18                   existing paid
# 671     no checking        36                   existing paid
# 242              <0        48             no credits/all paid
# 374        0<=X<200        60                        all paid
# 797     no checking        12  critical/other existing credit
# 81      no checking        15                   existing paid
# 600        0<=X<200         7                   existing paid
# 142              <0        27                   existing paid
# 527     no checking         4  critical/other existing credit
# 479              <0        15  critical/other existing credit
# 120              <0        21                   existing paid
# 228     no checking         9                   existing paid
# 274              <0        30                   existing paid
# 776     no checking        36  critical/other existing credit
# 685     no checking        60                   existing paid
# 34            >=200        12                   existing paid
# 104     no checking        12                   existing paid
# 94         0<=X<200        12                   existing paid
# 414              <0        24                   existing paid
# 718           >=200        24  critical/other existing credit
# 125              <0        12  critical/other existing credit
# 644              <0        18  critical/other existing credit
# 589              <0        12  critical/other existing credit
# 584     no checking        12                   existing paid
# 647     no checking        12                   existing paid
# 41         0<=X<200        12                   existing paid
# 473     no checking         6                   existing paid
# 974     no checking        30  critical/other existing credit
# 516              <0         6  critical/other existing credit
# 186        0<=X<200         9                        all paid
# 593        0<=X<200        24                   existing paid
# 578        0<=X<200        36  critical/other existing credit
# 964        0<=X<200         6                   existing paid
# 17               <0        30             no credits/all paid
# 484     no checking        12  critical/other existing credit
# 236        0<=X<200         6                   existing paid
# 538              <0        48                   existing paid
# 983              <0        36                   existing paid
# 971     no checking        24                   existing paid
# 885              <0        12                   existing paid
# 496        0<=X<200        36                   existing paid
# 868     no checking        36                   existing paid
# 614     no checking        18              delayed previously
# 314           >=200         4                   existing paid
# 437     no checking        24  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 486             radio/tv           3077              <100      1<=X<4
# 872             business           1382        100<=X<500      4<=X<7
# 404              new car           2899  no known savings         >=7
# 911  furniture/equipment           4736              <100          <1
# 531              new car           2631        100<=X<500      1<=X<4
# 608             radio/tv           2051              <100          <1
# 671             business           5742        100<=X<500      4<=X<7
# 242             used car           4605              <100         >=7
# 374                other          14782        100<=X<500         >=7
# 797  furniture/equipment           1258              <100          <1
# 81              radio/tv           1213       500<=X<1000         >=7
# 600             radio/tv           2329              <100          <1
# 142             radio/tv           3416              <100      1<=X<4
# 527             radio/tv           1503              <100      4<=X<7
# 479  furniture/equipment           1478              <100         >=7
# 120             radio/tv           1835              <100      1<=X<4
# 228             radio/tv           1478              <100      4<=X<7
# 274              repairs          11998              <100          <1
# 776              new car           3535              <100      4<=X<7
# 685              new car           6527  no known savings      1<=X<4
# 34   furniture/equipment           1474              <100          <1
# 104             used car           2445  no known savings          <1
# 94               new car           1318            >=1000         >=7
# 414              new car           1381  no known savings      1<=X<4
# 718             radio/tv           3148  no known savings      1<=X<4
# 125              new car           2121              <100      1<=X<4
# 644             radio/tv           1880              <100      4<=X<7
# 589  furniture/equipment           2246              <100         >=7
# 584              new car           2133  no known savings         >=7
# 647              new car           1386       500<=X<1000      1<=X<4
# 41              radio/tv           1158       500<=X<1000      1<=X<4
# 473           retraining           1238  no known savings  unemployed
# 974             radio/tv           2831              <100      1<=X<4
# 516              new car           1361              <100          <1
# 186             used car           5129              <100         >=7
# 593              new car           2718              <100      1<=X<4
# 578              new car           2820              <100          <1
# 964              repairs            454              <100          <1
# 17              business           8072  no known savings          <1
# 484              new car           1163       500<=X<1000      1<=X<4
# 236              new car          14555  no known savings  unemployed
# 538              new car           7763              <100         >=7
# 983             used car           8229              <100      1<=X<4
# 971              new car           7393              <100      1<=X<4
# 885            education            795              <100          <1
# 496  furniture/equipment           9034        100<=X<500          <1
# 868             business           7409  no known savings         >=7
# 614  furniture/equipment           1808              <100      4<=X<7
# 314              new car           1494  no known savings          <1
# 437              new car           1287            >=1000         >=7
#
#      installment_commitment     personal_status other_parties  ...  age  \
# 486                       2         male single          none  ...   52
# 872                       4         male single          none  ...   26
# 404                       4         male single          none  ...   43
# 911                       2  female div/dep/mar          none  ...   25
# 531                       2  female div/dep/mar          none  ...   28
# 608                       4         male single          none  ...   33
# 671                       2         male single          none  ...   31
# 242                       3         male single          none  ...   24
# 374                       3  female div/dep/mar          none  ...   60
# 797                       2  female div/dep/mar          none  ...   22
# 81                        4         male single          none  ...   47
# 600                       1  female div/dep/mar     guarantor  ...   45
# 142                       3         male single          none  ...   27
# 527                       2         male single          none  ...   42
# 479                       4         male single          none  ...   44
# 120                       3  female div/dep/mar          none  ...   25
# 228                       4         male single          none  ...   22
# 274                       1        male div/sep          none  ...   34
# 776                       4         male single          none  ...   37
# 685                       4         male single          none  ...   34
# 34                        4  female div/dep/mar          none  ...   33
# 104                       2        male mar/wid          none  ...   26
# 94                        4         male single          none  ...   54
# 414                       4  female div/dep/mar          none  ...   35
# 718                       3         male single          none  ...   31
# 125                       4         male single          none  ...   30
# 644                       4        male mar/wid          none  ...   32
# 589                       3         male single          none  ...   60
# 584                       4  female div/dep/mar          none  ...   52
# 647                       2  female div/dep/mar          none  ...   26
# 41                        3        male div/sep          none  ...   26
# 473                       4         male single          none  ...   36
# 974                       4  female div/dep/mar          none  ...   33
# 516                       2         male single          none  ...   40
# 186                       2  female div/dep/mar          none  ...   74
# 593                       3  female div/dep/mar          none  ...   20
# 578                       4        male div/sep          none  ...   27
# 964                       3        male mar/wid          none  ...   22
# 17                        2         male single          none  ...   25
# 484                       4         male single          none  ...   44
# 236                       1         male single          none  ...   23
# 538                       4         male single          none  ...   42
# 983                       2         male single          none  ...   26
# 971                       1         male single          none  ...   43
# 885                       4  female div/dep/mar          none  ...   53
# 496                       4         male single  co applicant  ...   29
# 868                       3         male single          none  ...   37
# 614                       4  female div/dep/mar          none  ...   22
# 314                       1         male single          none  ...   29
# 437                       4  female div/dep/mar          none  ...   37
#
#     other_payment_plans   housing existing_credits                        job  \
# 486                none       own                1                    skilled
# 872                none       own                2                    skilled
# 404                none       own                1                    skilled
# 911                bank       own                1         unskilled resident
# 531                none      rent                2                    skilled
# 608                none       own                1                    skilled
# 671                none       own                2                    skilled
# 242                none  for free                2                    skilled
# 374                bank  for free                2  high qualif/self emp/mgmt
# 797                none      rent                2         unskilled resident
# 81               stores       own                1                    skilled
# 600                none       own                1                    skilled
# 142                none       own                1  high qualif/self emp/mgmt
# 527                none       own                2         unskilled resident
# 479                none       own                2                    skilled
# 120                none       own                2                    skilled
# 228                none       own                1                    skilled
# 274                none       own                1         unskilled resident
# 776                none       own                2                    skilled
# 685                none  for free                1                    skilled
# 34                 bank       own                1  high qualif/self emp/mgmt
# 104                none      rent                1                    skilled
# 94                 none       own                1                    skilled
# 414                none       own                1                    skilled
# 718                none       own                2                    skilled
# 125                none       own                2                    skilled
# 644                none       own                2  high qualif/self emp/mgmt
# 589                none       own                2                    skilled
# 584                none  for free                1  high qualif/self emp/mgmt
# 647                none       own                1                    skilled
# 41                 none       own                1                    skilled
# 473                none       own                1  high qualif/self emp/mgmt
# 974                none       own                1                    skilled
# 516                none       own                1         unskilled resident
# 186                bank  for free                1  high qualif/self emp/mgmt
# 593                none      rent                1         unskilled resident
# 578                none       own                2                    skilled
# 964                none       own                1         unskilled resident
# 17                 bank       own                3                    skilled
# 484                none       own                1                    skilled
# 236                none       own                1    unemp/unskilled non res
# 538                bank  for free                1  high qualif/self emp/mgmt
# 983                none       own                1                    skilled
# 971                none       own                1         unskilled resident
# 885                none       own                1                    skilled
# 496                none      rent                1  high qualif/self emp/mgmt
# 868                none       own                2                    skilled
# 614                none       own                1                    skilled
# 314                none       own                1         unskilled resident
# 437                none       own                2                    skilled
#
#      num_dependents own_telephone  foreign_worker Prediction Actual Result
# 486               1           yes             yes          0             0
# 872               1           yes             yes          0             0
# 404               2          none             yes          0             0
# 911               1          none             yes          0             1
# 531               1           yes             yes          0             1
# 608               1          none             yes          0             0
# 671               1           yes             yes          0             0
# 242               2          none             yes          1             1
# 374               1           yes             yes          1             1
# 797               1          none             yes          0             0
# 81                1           yes             yes          0             0
# 600               1          none             yes          0             0
# 142               1          none             yes          1             0
# 527               2          none             yes          0             0
# 479               2           yes             yes          0             0
# 120               1           yes             yes          1             1
# 228               1          none             yes          0             1
# 274               1           yes             yes          1             1
# 776               1           yes             yes          0             0
# 685               2           yes             yes          0             0
# 34                1           yes             yes          0             0
# 104               1           yes             yes          0             0
# 94                1           yes             yes          0             0
# 414               1          none             yes          1             1
# 718               1           yes             yes          0             0
# 125               1          none             yes          0             0
# 644               1           yes             yes          0             0
# 589               1          none             yes          0             1
# 584               1           yes             yes          0             0
# 647               1          none             yes          0             1
# 41                1           yes             yes          0             0
# 473               2           yes             yes          0             0
# 974               1           yes             yes          0             0
# 516               2          none              no          0             0
# 186               2           yes             yes          0             1
# 593               1           yes             yes          1             1
# 578               1          none             yes          1             1
# 964               1          none             yes          1             0
# 17                1          none             yes          1             0
# 484               1           yes             yes          0             0
# 236               1           yes             yes          1             1
# 538               1          none             yes          1             1
# 983               2          none             yes          0             1
# 971               2          none             yes          0             0
# 885               1          none             yes          1             1
# 496               1           yes             yes          1             1
# 868               1          none             yes          0             0
# 614               1          none             yes          0             1
# 314               2          none              no          0             0
# 437               1           yes             yes          0             0
#
# [50 rows x 22 columns]

# %%
finalDataFrame[50:]
# Out:
#     checking_status  duration                  credit_history  \
# 258     no checking        15                   existing paid
# 194        0<=X<200        45                   existing paid
# 794     no checking        24                   existing paid
# 35         0<=X<200        45  critical/other existing credit
# 494              <0        12  critical/other existing credit
# 967     no checking        15                   existing paid
# 50         0<=X<200        24              delayed previously
# 267     no checking        24                   existing paid
# 207        0<=X<200        12  critical/other existing credit
# 358     no checking        12                   existing paid
# 711              <0         6                        all paid
# 816     no checking         6                   existing paid
# 331     no checking        18  critical/other existing credit
# 90      no checking        12  critical/other existing credit
# 6       no checking        24                   existing paid
# 929              <0        12              delayed previously
# 746              <0        15                   existing paid
# 824     no checking        18  critical/other existing credit
# 453     no checking        24                   existing paid
# 464     no checking        18                   existing paid
# 148              <0        36  critical/other existing credit
# 951              <0        36              delayed previously
# 672     no checking        60                   existing paid
# 84               <0        10                   existing paid
# 244     no checking        12                        all paid
# 59               <0        36  critical/other existing credit
# 968     no checking        42                   existing paid
# 449        0<=X<200        15              delayed previously
# 956           >=200        30  critical/other existing credit
# 180     no checking        36              delayed previously
# 56         0<=X<200        12                   existing paid
# 654     no checking        24  critical/other existing credit
# 742     no checking        21                   existing paid
# 3                <0        42                   existing paid
# 826              <0        18  critical/other existing credit
# 345     no checking        15  critical/other existing credit
# 756           >=200         6  critical/other existing credit
# 659        0<=X<200        18  critical/other existing credit
# 223     no checking        24              delayed previously
# 577     no checking        24  critical/other existing credit
# 154        0<=X<200        24              delayed previously
# 78      no checking        54             no credits/all paid
# 205              <0        30  critical/other existing credit
# 200     no checking         9  critical/other existing credit
# 581        0<=X<200        12  critical/other existing credit
# 156              <0         9  critical/other existing credit
# 430     no checking         5                   existing paid
# 550     no checking        12  critical/other existing credit
# 555        0<=X<200        12                   existing paid
# 443     no checking        12                   existing paid
#
#                  purpose  credit_amount    savings_status  employment  \
# 258             used car           3812        100<=X<500          <1
# 194             radio/tv           3031        100<=X<500      1<=X<4
# 794  furniture/equipment           3062       500<=X<1000         >=7
# 35              radio/tv           4746              <100          <1
# 494              new car           2122              <100      1<=X<4
# 967             radio/tv           3568              <100         >=7
# 50   furniture/equipment           2333  no known savings          <1
# 267             radio/tv           1533              <100          <1
# 207   domestic appliance           1424              <100      4<=X<7
# 358             radio/tv            776              <100      1<=X<4
# 711            education           1198              <100         >=7
# 816   domestic appliance           1338       500<=X<1000      1<=X<4
# 331            education           1864        100<=X<500      1<=X<4
# 90              radio/tv            618              <100         >=7
# 6    furniture/equipment           2835       500<=X<1000         >=7
# 929              new car           1344              <100      1<=X<4
# 746              new car           2511              <100  unemployed
# 824  furniture/equipment           3780              <100          <1
# 453             used car           2670              <100         >=7
# 464             business           1950              <100      4<=X<7
# 148  furniture/equipment           5371              <100      1<=X<4
# 951             business           2145              <100      4<=X<7
# 672              new car          10366              <100         >=7
# 84              radio/tv           2315              <100         >=7
# 244           retraining           3447       500<=X<1000      1<=X<4
# 59   furniture/equipment           6229              <100          <1
# 968             radio/tv           7166  no known savings      4<=X<7
# 449              repairs           1512            >=1000      1<=X<4
# 956             radio/tv           3656  no known savings         >=7
# 180             business           9572              <100          <1
# 56              radio/tv           6468  no known savings  unemployed
# 654             used car           2346              <100      4<=X<7
# 742             radio/tv           3160  no known savings         >=7
# 3    furniture/equipment           7882              <100      4<=X<7
# 826              new car           3966              <100         >=7
# 345             radio/tv           1459              <100      1<=X<4
# 756              new car           1299              <100      1<=X<4
# 659  furniture/equipment           6361              <100         >=7
# 223             business           2978  no known savings      1<=X<4
# 577            education           1927  no known savings      1<=X<4
# 154             business           6967        100<=X<500      4<=X<7
# 78              used car           9436  no known savings      1<=X<4
# 205             used car          10623              <100         >=7
# 200            education            936       500<=X<1000         >=7
# 581              new car           3124              <100          <1
# 156              repairs           1288        100<=X<500         >=7
# 430             business           3448              <100      4<=X<7
# 550              repairs            996  no known savings      4<=X<7
# 555             radio/tv           1331              <100          <1
# 443            education            719              <100         >=7
#
#      installment_commitment     personal_status other_parties  ...  age  \
# 258                       1  female div/dep/mar          none  ...   23
# 194                       4         male single     guarantor  ...   21
# 794                       4         male single          none  ...   32
# 35                        4         male single          none  ...   25
# 494                       3         male single          none  ...   39
# 967                       4  female div/dep/mar          none  ...   54
# 50                        4         male single          none  ...   29
# 267                       4  female div/dep/mar          none  ...   38
# 207                       4         male single          none  ...   26
# 358                       4        male mar/wid          none  ...   28
# 711                       4  female div/dep/mar          none  ...   35
# 816                       1        male div/sep          none  ...   62
# 331                       4  female div/dep/mar          none  ...   30
# 90                        4         male single          none  ...   56
# 6                         3         male single          none  ...   53
# 929                       4         male single          none  ...   43
# 746                       1  female div/dep/mar          none  ...   23
# 824                       3        male div/sep          none  ...   35
# 453                       4         male single          none  ...   35
# 464                       4         male single          none  ...   34
# 148                       3         male single     guarantor  ...   28
# 951                       2         male single          none  ...   24
# 672                       2         male single          none  ...   42
# 84                        3         male single          none  ...   52
# 244                       4  female div/dep/mar          none  ...   35
# 59                        4  female div/dep/mar  co applicant  ...   23
# 968                       2        male mar/wid          none  ...   29
# 449                       3        male mar/wid          none  ...   61
# 956                       4         male single          none  ...   49
# 180                       1        male div/sep          none  ...   28
# 56                        2         male single          none  ...   52
# 654                       4         male single          none  ...   35
# 742                       4         male single          none  ...   41
# 3                         2         male single     guarantor  ...   45
# 826                       1  female div/dep/mar          none  ...   33
# 345                       4  female div/dep/mar          none  ...   43
# 756                       1         male single          none  ...   74
# 659                       2         male single          none  ...   41
# 223                       4         male single          none  ...   32
# 577                       3  female div/dep/mar          none  ...   33
# 154                       4         male single          none  ...   36
# 78                        2         male single          none  ...   39
# 205                       3         male single          none  ...   38
# 200                       4         male single          none  ...   52
# 581                       1         male single          none  ...   49
# 156                       3         male single     guarantor  ...   48
# 430                       1         male single          none  ...   74
# 550                       4  female div/dep/mar          none  ...   23
# 555                       2         male single          none  ...   22
# 443                       4         male single          none  ...   41
#
#     other_payment_plans   housing existing_credits                        job  \
# 258                none       own                1                    skilled
# 194                none      rent                1                    skilled
# 794                none      rent                1                    skilled
# 35                 none       own                2         unskilled resident
# 494                none      rent                2         unskilled resident
# 967                bank      rent                1  high qualif/self emp/mgmt
# 50                 bank       own                1         unskilled resident
# 267              stores       own                1                    skilled
# 207                none       own                1                    skilled
# 358                none       own                1                    skilled
# 711                none  for free                1                    skilled
# 816                none       own                1                    skilled
# 331                none       own                2                    skilled
# 90                 none       own                1                    skilled
# 6                  none       own                1                    skilled
# 929                none       own                2         unskilled resident
# 746                none      rent                1                    skilled
# 824                none       own                2  high qualif/self emp/mgmt
# 453                none       own                1  high qualif/self emp/mgmt
# 464              stores       own                2                    skilled
# 148                none       own                2                    skilled
# 951                none       own                2                    skilled
# 672                none       own                1  high qualif/self emp/mgmt
# 84                 none       own                1         unskilled resident
# 244                none       own                1         unskilled resident
# 59                 none      rent                2         unskilled resident
# 968                none      rent                1                    skilled
# 449              stores       own                2                    skilled
# 956              stores       own                2         unskilled resident
# 180                none       own                2                    skilled
# 56                 none       own                1  high qualif/self emp/mgmt
# 654                none       own                2                    skilled
# 742                none       own                1                    skilled
# 3                  none  for free                1                    skilled
# 826                bank      rent                3                    skilled
# 345                none       own                1         unskilled resident
# 756                none       own                3    unemp/unskilled non res
# 659                none       own                1                    skilled
# 223                none       own                2                    skilled
# 577                none       own                2                    skilled
# 154                none      rent                1  high qualif/self emp/mgmt
# 78                 none       own                1         unskilled resident
# 205                none  for free                3  high qualif/self emp/mgmt
# 200                none       own                2                    skilled
# 581                bank       own                2         unskilled resident
# 156                none       own                2                    skilled
# 430                none       own                1         unskilled resident
# 550                none       own                2                    skilled
# 555              stores       own                1                    skilled
# 443                bank       own                1         unskilled resident
#
#      num_dependents own_telephone  foreign_worker Prediction Actual Result
# 258               1           yes             yes          0             0
# 194               1          none             yes          1             1
# 794               1           yes             yes          0             0
# 35                1          none             yes          1             1
# 494               2          none              no          0             0
# 967               1           yes             yes          0             0
# 50                1          none             yes          0             0
# 267               1           yes             yes          0             0
# 207               1          none             yes          0             0
# 358               1          none             yes          0             0
# 711               1          none             yes          1             1
# 816               1          none             yes          0             0
# 331               1          none             yes          0             1
# 90                1          none             yes          0             0
# 6                 1          none             yes          0             0
# 929               2          none             yes          1             0
# 746               1          none             yes          1             0
# 824               1           yes             yes          0             0
# 453               1           yes             yes          0             0
# 464               1           yes             yes          0             0
# 148               1          none             yes          0             0
# 951               1           yes             yes          0             1
# 672               1           yes             yes          0             0
# 84                1          none             yes          0             0
# 244               2          none             yes          0             0
# 59                1           yes             yes          1             1
# 968               1           yes             yes          0             0
# 449               1          none             yes          0             1
# 956               1          none             yes          0             0
# 180               1          none             yes          0             1
# 56                1           yes             yes          0             1
# 654               1           yes             yes          0             0
# 742               1           yes             yes          0             0
# 3                 2          none             yes          0             0
# 826               1           yes             yes          1             1
# 345               1          none             yes          0             0
# 756               2          none              no          0             0
# 659               1           yes             yes          0             0
# 223               2           yes             yes          0             0
# 577               1           yes             yes          0             0
# 154               1           yes             yes          0             0
# 78                2          none             yes          0             0
# 205               2           yes             yes          1             0
# 200               1           yes             yes          0             0
# 581               2          none             yes          0             0
# 156               2          none              no          0             0
# 430               1          none             yes          0             0
# 550               1          none             yes          0             0
# 555               1          none             yes          0             1
# 443               2          none             yes          1             1
#
# [50 rows x 22 columns]
